# %%
import pandas as pd

df = pd.read_csv('films.csv')
df
# Out:
#                                                acteurs  \
# 0    Tim Robbins,Morgan Freeman,Bob Gunton,William ...
# 1    Arnold Schwarzenegger,Linda Hamilton,Edward Fu...
# 2    Michael J. Fox,Christopher Lloyd,Lea Thompson,...
# 3    Tom Hanks,Michael Clarke Duncan,David Morse,Bo...
# 4    Roberto Benigni,Nicoletta Braschi,Giorgio Cant...
# ..                                                 ...
# 245  Marlon Brando,Al Pacino,James Caan,Diane Keato...
# 246  Christian Bale,Heath Ledger,Aaron Eckhart,Mich...
# 247  Maria Falconetti,Eugene Silvain,André Berley,M...
# 248  Robert De Niro,James Woods,Elizabeth McGovern,...
# 249  Charles Chaplin,Paulette Goddard,Jack Oakie,Re...
#
#                                            description  duree  \
# 0    Over the course of several years, two convicts...    142
# 1    A cyborg, identical to the one who failed to k...    137
# 2    Marty McFly, a 17-year-old high school student...    116
# ...

# %%
#drop de colonnes data leaking -> score ?
#drop de colonnes que je juge inutile -> year 
#drop de colonnes dont on ne peux pas se servir car besoin de NLP -> titre, titre_original, description 
df = df.drop(['year', 'titre', 'titre_original', 'description'], axis=1)

df
# Out:
#                                                acteurs  duree  \
# 0    Tim Robbins,Morgan Freeman,Bob Gunton,William ...    142
# 1    Arnold Schwarzenegger,Linda Hamilton,Edward Fu...    137
# 2    Michael J. Fox,Christopher Lloyd,Lea Thompson,...    116
# 3    Tom Hanks,Michael Clarke Duncan,David Morse,Bo...    189
# 4    Roberto Benigni,Nicoletta Braschi,Giorgio Cant...    116
# ..                                                 ...    ...
# 245  Marlon Brando,Al Pacino,James Caan,Diane Keato...    175
# 246  Christian Bale,Heath Ledger,Aaron Eckhart,Mich...    152
# 247  Maria Falconetti,Eugene Silvain,André Berley,M...    114
# 248  Robert De Niro,James Woods,Elizabeth McGovern,...    229
# 249  Charles Chaplin,Paulette Goddard,Jack Oakie,Re...    125
#
#                        genre langue_origine           pays  public
# 0                      Drama        English  United States       R
# 1    Action,Adventure,Sci-Fi        English  United States       R
# ...

# %%
#

# %%
#drop de colonnes que je trouve inutile ? year
