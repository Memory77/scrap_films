# %%
import pandas as pd

df = pd.read_csv('dataset.csv')
df.head(30)
# Out:
#                                               acteurs  \
# 0      Raphaël Personnaz,Doria Tillier,Jeanne Balibar
# 1   Vincent Lindon,Karole Rocher,Stefan Virgil Stoica
# 2        Maxime Gasteuil,Zabou Breitman,Romain Lancry
# 3           Olivia Colman,Jessie Buckley,Anjana Vasan
# 4      Guillaume Canet,Alba Rohrwacher,Sharif Andoura
# 5             Agnès Jaoui,William Lebghil,Salif Cissé
# 6   Jasmine Trinca,Leïla Bekhti,Rafaëlle Sonnevill...
# 7   Christian Clavier,Marianne Denicourt,Didier Bo...
# 8                Karin Viard,Ana Girardot,Cédric Kahn
# 9            Audrey Lamy,Fabrice Eboué,Anouk Grinberg
# 10      Blanche Gardin,Michel Houellebecq,Luc Schwarz
# 11     Sandra Hüller,Milo Machado-Graner,Swann Arlaud
# 12        Franck Dubosc,Reem Kherici,Philippe Lacheau
# 13         Sydney Sweeney,Glen Powell,Alexandra Shipp
# 14  Louise Bourgoin,Xavier Lacaille,Francesco Mont...
# 15                 Kev Adams,Jean Reno,Daniel Prévost
# ...

# %%
df.shape
# Out:
# (1536, 7)

# %%
# Supprimer les lignes où la colonne 'A' est nulle
df = df.dropna(subset=['entrees'])

# %%
df.shape
# Out:
# (594, 7)

# %%
#drop de colonnes que je trouve inutile ? year
